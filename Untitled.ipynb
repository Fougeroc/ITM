# %%
g = DiGraph({0:[1,2,3], 2:[4], 4:[1], 1:[0], 3:[2]}); g
# Out:
# Digraph on 5 vertices

# %%
g.path_semigroup?

# %%
Q = DiGraph({1:{2:['a','c']}, 2:{3:['b']}})
F = Q.path_semigroup(); F
# Out:
# Partial semigroup formed by the directed paths of Multi-digraph on 3 vertices

# %%
sage: g = DiGraph({0:[1,2,3], 2:[4]}); g
# Out:
# Multi-digraph on 3 vertices

# %%
F.iter_paths_by_length_and_startpoint(4,1)
# Out:
# <generator object iter_paths_by_length_and_startpoint at 0x7f5a4eac0370>
